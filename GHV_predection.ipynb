# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# Data Collection And Analysis

# %%
#loading the data from csv file to a pandas dataframe
GHV_dataset = pd.read_csv('/content/GHI_Report_ .csv')
GHV_dataset
# Out:
#      Economy      Fam   Health  Freedom  H_Score
# 0    1.39651  1.34951  0.94143  0.66557    7.587
# 1    1.30232  1.40223  0.94784  0.62877    7.561
# 2    1.32548  1.36058  0.87464  0.64938    7.527
# 3    1.45900  1.33095  0.88521  0.66973    7.522
# 4    1.32629  1.32261  0.90563  0.63297    7.427
# ..       ...      ...      ...      ...      ...
# 153  0.22208  0.77370  0.42864  0.59201    3.465
# 154  0.28665  0.35386  0.31910  0.48450    3.340
# 155  0.66320  0.47489  0.72193  0.15684    3.006
# 156  0.01530  0.41587  0.22396  0.11850    2.905
# 157  0.20868  0.13995  0.28443  0.36453    2.839
#
# [158 rows x 5 columns]

# %%
# First 5 rows of the dataset
GHV_dataset.head()
# Out:
#    Economy      Fam   Health  Freedom  H_Score
# 0  1.39651  1.34951  0.94143  0.66557    7.587
# 1  1.30232  1.40223  0.94784  0.62877    7.561
# 2  1.32548  1.36058  0.87464  0.64938    7.527
# 3  1.45900  1.33095  0.88521  0.66973    7.522
# 4  1.32629  1.32261  0.90563  0.63297    7.427

# %%
#Shape od dataset
GHV_dataset.shape
# Out:
# (158, 5)

# %%
# info of dataset
GHV_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Economy  158 non-null    float64
#  1   Fam      158 non-null    float64
#  2   Health   158 non-null    float64
#  3   Freedom  158 non-null    float64
#  4   H_Score  158 non-null    float64
# dtypes: float64(5)
# memory usage: 6.3 KB

# %%
#showing the null values
#Checking the missing values
GHV_dataset.isnull().sum()
# Out:
# Economy    0
# Fam        0
# Health     0
# Freedom    0
# H_Score    0
# dtype: int64

# %%
# Statsitical measures of the dataset
GHV_dataset.describe()
# Out:
#           Economy         Fam      Health     Freedom     H_Score
# count  158.000000  158.000000  158.000000  158.000000  158.000000
# mean     0.846137    0.991046    0.630259    0.428615    5.375734
# std      0.403121    0.272369    0.247078    0.150693    1.145010
# min      0.000000    0.000000    0.000000    0.000000    2.839000
# 25%      0.545808    0.856823    0.439185    0.328330    4.526000
# 50%      0.910245    1.029510    0.696705    0.435515    5.232500
# 75%      1.158448    1.214405    0.811013    0.549092    6.243750
# max      1.690420    1.402230    1.025250    0.669730    7.587000

# %%
#Distribution of age value
sns.catplot(x = 'H_Score', data = GHV_dataset, kind = 'count')

# %%
# seperating the data and label
X = GHV_dataset.drop(columns = 'H_Score', axis = 1)

# %%
Y = GHV_dataset.H_Score

# %%
print(X)
# Out:
#      Economy      Fam   Health  Freedom
# 0    1.39651  1.34951  0.94143  0.66557
# 1    1.30232  1.40223  0.94784  0.62877
# 2    1.32548  1.36058  0.87464  0.64938
# 3    1.45900  1.33095  0.88521  0.66973
# 4    1.32629  1.32261  0.90563  0.63297
# ..       ...      ...      ...      ...
# 153  0.22208  0.77370  0.42864  0.59201
# 154  0.28665  0.35386  0.31910  0.48450
# 155  0.66320  0.47489  0.72193  0.15684
# 156  0.01530  0.41587  0.22396  0.11850
# 157  0.20868  0.13995  0.28443  0.36453
#
# [158 rows x 4 columns]

# %%
print(Y)
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: H_Score, Length: 158, dtype: float64

# %% [markdown]
# Splitting the data into training and testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y ,test_size =0.2 , random_state =2 )

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (158, 4) (126, 4) (32, 4)

# %%
# Model Training

# %%
# Calling Linear Regression Model
regressor = LinearRegression()

# %%
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# predection on training the Data
training_data_predection = regressor.predict(X_train)

# %%
# R Square Value
r2_train = metrics.r2_score(Y_train,training_data_predection)
print( "R Square Value " , r2_train )
# Out:
# R Square Value  0.7735372885781695

# %%
# R square value on testing data

testing_data_prediction = regressor.predict(X_test)

r2_test = metrics.r2_score(Y_test,testing_data_prediction)
print( "R Square Value " , r2_test )
# Out:
# R Square Value  0.7445666923978922

# %%
input_data =(1.3965,1.34951,	0.94143,	0.66557)

#Chaning inp_data into a numpy array
input_data_as_numpy_array = np.asarray(input_data)

#Reshaping the array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)


#Predicting the cost
prediction = regressor.predict(input_data_reshaped)
print("The Cost of your Model Insurance is:", prediction)
# Out:
# The Cost of your Model Insurance is: [7.06981675]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Out:
# Predictied Quality of the wine is: [6]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
